# %%
import unittest
from abc import ABC, abstractmethod

# %%
class PoliticaDesconto(ABC):
    @abstractmethod
    def calcular(self, valor, extra=0):
        pass

class SemDesconto(PoliticaDesconto):
    def calcular(self, valor, extra=0):
        return valor

class DescontoPercentual(PoliticaDesconto):
    def calcular(self, valor, extra=0):
        return valor * (1 - extra / 100)

class DescontoFixo(PoliticaDesconto):
    def calcular(self, valor, extra=0):
        return max(0, valor - extra)

# Contexto que utiliza a Strategy
class CalculadoraDesconto:
    def __init__(self):
        self.estrategias = {
            "nenhum": SemDesconto(),
            "percentual": DescontoPercentual(),
            "fixo": DescontoFixo()
        }

    def calcular(self, valor, tipo, extra=0):
        estrategia = self.estrategias.get(tipo, SemDesconto())
        return estrategia.calcular(valor, extra)

# %%
class TestCalculadoraDesconto(unittest.TestCase):
    def test_sem_desconto(self):
        calc = CalculadoraDesconto()
        self.assertEqual(calc.calcular(100, "nenhum"), 100) 

    def test_desconto_percentual(self):
        calc = CalculadoraDesconto()
        # Exemplo: 10% de 100 = 90
        self.assertEqual(calc.calcular(100, "percentual", 10), 90) 

    def test_desconto_fixo_cupom(self):
        calc = CalculadoraDesconto()
        # Exemplo: 100 - 20 = 80
        self.assertEqual(calc.calcular(100, "fixo", 20), 80)

    def test_desconto_fixo_nao_negativo(self):
        calc = CalculadoraDesconto()
        # Valor 10 - cupom 20 não deve ser -10, mas sim 0
        self.assertEqual(calc.calcular(10, "fixo", 20), 0)

# %%
if __name__ == "__main__":
    print("Inicio dos Testes")
    unittest.main(argv=['first-arg-is-ignored'],exit=False)
# Out:
# FFFF
# ======================================================================
# FAIL: test_desconto_fixo_cupom (__main__.TestCalculadoraDesconto.test_desconto_fixo_cupom)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\a2453266\AppData\Local\Temp\ipykernel_5156\2513167724.py", line 18, in test_desconto_fixo_cupom
#     self.assertEqual(calc.calcular(100, "fixo", 20), 80)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: None != 80
#
# ======================================================================
# FAIL: test_desconto_fixo_nao_negativo (__main__.TestCalculadoraDesconto.test_desconto_fixo_nao_negativo)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\a2453266\AppData\Local\Temp\ipykernel_5156\2513167724.py", line 23, in test_desconto_fixo_nao_negativo
#     self.assertEqual(calc.calcular(10, "fixo", 20), 0)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: None != 0
#
# ======================================================================
# FAIL: test_desconto_percentual (__main__.TestCalculadoraDesconto.test_desconto_percentual)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\a2453266\AppData\Local\Temp\ipykernel_5156\2513167724.py", line 13, in test_desconto_percentual
#     self.assertEqual(calc.calcular(100, "percentual", 10), 90)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: None != 90
#
# ======================================================================
# FAIL: test_sem_desconto (__main__.TestCalculadoraDesconto.test_sem_desconto)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\a2453266\AppData\Local\Temp\ipykernel_5156\2513167724.py", line 8, in test_sem_desconto
#     self.assertEqual(calc.calcular(100, "nenhum"), 100)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: None != 100
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.003s
#
# FAILED (failures=4)
# Inicio dos Testes
